# %%
#import libraries
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from keras import backend as K
import tensorflow as tf
print(tf.__version__)

import numpy as np
import pandas as pd
import os
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose 

from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

tf.compat.v1.enable_eager_execution()

import pandas as pd
#import data

#import main data

df = pd.read_csv('data2021.csv')
df = df.drop(["Unnamed: 0"],axis=1)

branches = [9,12,1,10,2]
products = [31,21,31,48,1,29]

df = df[df['branch_code'].isin(branches)]
df = df[df['item_cat'].isin(products)]

df = df.reset_index().drop(["index"],axis=1)

#create data for all, and just for 2019 to test it

df_2019 = df[df["year"]==2019]

df = df[df["year"]!=2019]


# make a prediction with a stacking ensemble
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import StackingRegressor
from sklearn.neural_network import MLPRegressor


X = df.drop(["sales","ym"],axis=1)

y = df[["sales"]]

from sklearn.model_selection import KFold, cross_val_score, train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

X_test_orginal = X_test

X_train = pd.get_dummies(X_train, columns=['branch_code', 'item_cat', 'promotion', 'm'])
X_test = pd.get_dummies(X_test, columns=['branch_code', 'item_cat', 'promotion', 'm'])

# define the base models
level0 = list()
level0.append(('knn', KNeighborsRegressor(n_neighbors=10)))
level0.append(('cart', DecisionTreeRegressor()))
level0.append(('RF', RandomForestRegressor(n_estimators=100,max_features='log2', verbose=1)))
level0.append(('svm', SVR()))
level0.append(('nn', MLPRegressor(random_state=1, max_iter=500)))

# define meta learner model
level1 = LinearRegression()
# define the stacking ensemble
model = StackingRegressor(estimators=level0, final_estimator=level1, cv=5)
# fit the model on all available data
model.fit(X_train, y_train)

# make a prediction for one example
yhat = model.predict(X_test)

from sklearn.metrics import r2_score

print(r2_score(y_test, yhat))

#we need to see how our model did on unseen data that is in the future, to see its forcasting power

#we take the validation dataset which is in the year 2019, and we take the month of Feburary

feb = df_2019[df_2019["m"]==2]

#keep the oringal dataset to make it easz to tranform it back from the get_dummies
feb_or = feb

#encode the categorlical data
feb = pd.get_dummies(feb, columns=['branch_code', 'item_cat', 'promotion', 'm'])

#drop uneeded columns
feb2 = feb.drop(["ym","sales"],axis=1)

#enter missing columns
for i in list(set(X_test.columns).difference(feb2.columns)):
    
    feb2[i] = 0

#predict it using our Stacking model
yhat = model.predict(feb2)

#add our prediction to the dataset of Feburary
feb_or["yhat"] = yhat

#lets see how good our model did
print(r2_score(feb_or["sales"], feb_or["yhat"]))

#lets plot the results. (pay attention the graph to understand it well, each point is an obserbvation in the month of Feb)
feb_or.groupby(["branch_code","item_cat","ym"]).sum().plot(figsize=(20,20))

#now we need to add the prediction of LSTM and the predictions of FACEBOOK prophet and see if we can get a better reuslts
fbpred = []
fbpred1 = []
fbpred2 = []

import pandas as pd
from fbprophet import Prophet


for i in list(df["branch_code"].unique()):
    for y in list(df["item_cat"].unique()):
        
        x = df[(df["branch_code"]==i)&(df["item_cat"]==y)][["ym","sales"]].groupby("ym").sum().reset_index().rename({"ym":"ds","sales":"y"},axis=1)
        
        m = Prophet(seasonality_mode='multiplicative').fit(x)
        future = m.make_future_dataframe(periods=3652)
        
        m = Prophet(seasonality_mode='multiplicative', mcmc_samples=300).fit(x)
        fcst = m.predict(future)

        future = m.make_future_dataframe(periods=120, freq='MS')
        fcst = m.predict(future)
        
        num = max(0, int(fcst.set_index("ds")[71:72]["yhat"]))
        brnach_code1 = i
        product_id = y
        
        
        
        fbpred.append(num)
        fbpred1.append(brnach_code1)
        fbpred2.append(product_id)
        
fp = pd.DataFrame()

fp["pred"] = fbpred
fp["branch"] = fbpred1
fp["product"] = fbpred2

fp

final1 = pd.merge(feb_or, fp,  how='left', left_on=['branch_code','item_cat'], right_on = ['branch','product'])
final1.groupby(["branch_code","item_cat","ym"]).sum().plot(figsize=(20,20))

#LSTM

import pandas as pd
#import data

#import main data
df = pd.read_csv('data2021.csv')
df = df.drop(["Unnamed: 0"],axis=1)

branches = [9,12,1,10,2]
products = [31,21,31,48,1,29]

df = df[df['branch_code'].isin(branches)]
df = df[df['item_cat'].isin(products)]

df = df.reset_index().drop(["index"],axis=1)

#now we need to add the prediction of LSTM and the predictions of FACEBOOK prophet and see if we can get a better reuslts
fbpred = []
fbpred1 = []
fbpred2 = []

fp = pd.DataFrame()

import pandas as pd
from fbprophet import Prophet
import numpy as numpy
import math


for i in list(df["branch_code"].unique()):
    for y in list(df["item_cat"].unique()):
        
        print(i)
        print(y)
        
        x = df[(df["branch_code"]==i)&(df["item_cat"]==y)][["ym","sales"]].groupby("ym").sum().reset_index().rename({"ym":"ds","sales":"y"},axis=1)
        
        x = x.set_index("ds")
        # fix random seed for reproducibility
        seed = numpy.random.seed(7)

        # normalize the dataset
        data_range = (-1, 1)
        scaler = MinMaxScaler(feature_range=data_range)        # scaler can also de-normalize the dataset by scaler.inverse_transform(), useful for actual prediction
        dataset_scaled = scaler.fit_transform(x)
        #dataset_scaled = numpy.array(dataset_scaled)

        # split into train and test sets
        train_size = int(len(dataset_scaled) * 0.67)
        test_size = len(dataset_scaled) - train_size
        train, test = dataset_scaled[0:train_size,:], dataset_scaled[train_size:len(x),:]
        print(len(train), len(test))

        # convert an array of values into a dataset matrix
        def create_dataset(data, look_back=1):
            dataX, dataY = [], []
            i_range = len(data) - look_back - 1
            print(i_range)
            for i in range(0, i_range):
                dataX.append(data[i:(i+look_back)])    # index can move down to len(dataset)-1
                dataY.append(data[i + look_back])      # Y is the item that skips look_back number of items

            return numpy.array(dataX), numpy.array(dataY)

        # try it
        look_back = 4
        dataX, dataY = create_dataset(dataset_scaled, look_back=look_back)

        print("X shape:", dataX.shape)
        print("Y shape:", dataY.shape)

        print("Xt-3     Xt-2      Xt-1      Xt        Y")
        print("---------------------------------------------")
        for z in range(len(dataX)): 
            print('%.2f   %.2f    %.2f    %.2f    %.2f' % (dataX[z][0][0], dataX[z][1][0], dataX[z][2][0], dataX[z][3][0], dataY[z][0]))


        # Reshape to (samples, timestep, features)
        dataX = numpy.reshape(dataX, (dataX.shape[0], 1, dataX.shape[1]))

        print("X shape:", dataX.shape)

        # reshape into X=t and Y=t+1
        look_back = 1
        trainX, trainY = create_dataset(train, look_back)      # trainX is input, trainY is expected output
        testX, testY = create_dataset(test, look_back)


        # reshape input to be [samples, time steps, features]
        print("Original trainX shape:", trainX.shape)
        trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))     # timestep = 1, input_dim = trainX.shape[1]
        testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))
        print("New trainX shape:", trainX.shape)
        print("trainY shape:", trainY.shape)
        print("trainY example:", trainY[0])


        # create and fit the LSTM network
        from keras.layers import Dropout

        batch_size = 1
        timesteps = trainX.shape[1]
        input_dim = trainX.shape[2]

        model = Sequential()
        #model.add(LSTM(8, input_shape=(1, look_back)))    # 4 or 8 is the number of LSTM units or dimensions of output of LSTM layer, can be any integer. input_shape must show up in the first layer
        model.add(LSTM(4, batch_input_shape=(1, 1, 1)))
        model.add(Dense(10))    # not necessary, but just want to try it
        #model.add(Dropout(0.8))
        model.add(Dense(1))
        model.compile(loss='mean_squared_error', optimizer='adam')
        model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)   # it turns out that epochs = 15 is enough, 100 is not necessary


        # make predictions
        trainPredict = model.predict(trainX, batch_size)
        testPredict = model.predict(testX, batch_size)      

        # invert predictions
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY = scaler.inverse_transform(trainY)               # trainY is of shape (samples, features) while trainX is of (samples, timesteps, features) )
        testPredict = scaler.inverse_transform(testPredict)
        testY = scaler.inverse_transform(testY)

        print("trainY shape:", trainY.shape)
        print("trainPredict shape:", trainPredict.shape)
        print("testY shape:", testY.shape)
        print("testPredict shape:", testPredict.shape)

        # calculate root mean squared error
        trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
        print('Train Score: %.2f RMSE' % (trainScore))
        testScore = math.sqrt(mean_squared_error(testY, testPredict))
        print('Test Score: %.2f RMSE' % (testScore))


        # shift train predictions for plotting
        trainPredictPlot = numpy.empty_like(x)
        trainPredictPlot[:, :] = numpy.nan
        #print(trainPredictPlot[0])
        trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

        # shift test predictions for plotting
        testPredictPlot = numpy.empty_like(x)
        testPredictPlot[:, :] = numpy.nan
        testPredictPlot[len(trainPredict)+(look_back*2)+1:len(x)-1, :] = testPredict

        # plot baseline and predictions
        plt.plot(scaler.inverse_transform(dataset_scaled))
        #plt.plot(dataset_scaled)
        plt.plot(trainPredictPlot)
        plt.plot(testPredictPlot)
        plt.show()

        x = x.reset_index()
        x["test"] = testPredictPlot
        
        if len(x[x["ds"]=="2019-02"]["test"])!=0:
            num = int(x[x["ds"]=="2019-02"]["test"])
            brnach_code1 = i
            product_id = y

            x = df[(df["branch_code"]==i)&(df["item_cat"]==y)][["ym","sales"]].groupby("ym").sum().reset_index().rename({"ym":"ds","sales":"y"},axis=1)





            fbpred.append(num)
            fbpred1.append(brnach_code1)
            fbpred2.append(product_id)
        

fp["pred"] = fbpred
fp["branch"] = fbpred1
fp["product"] = fbpred2


final2 = pd.merge(final1, fp,  how='left', left_on=['branch_code','item_cat'], right_on = ['branch','product'])
final2.groupby(["branch_code","item_cat","ym"]).sum().plot(figsize=(20,20))

final3 = final2[["branch_code","item_cat","ym","yhat","pred_x","pred_y","sales"]].groupby(["branch_code","item_cat","ym"]).sum().reset_index()

final3["end"] = (final3["yhat"] + final3["pred_x"] + final3["pred_y"] )/3

final3.groupby(["branch_code","item_cat","ym"]).sum()[["sales","end"]].plot(figsize=(20,20))

print('Stacking = ',r2_score(final3["sales"],final3["yhat"]))
print('FP = ',r2_score(final3["sales"],final3["pred_x"]))
print('LSTM = ',r2_score(final3["sales"],final3["pred_y"]))
print('AVG = ',r2_score(final3["sales"],final3["end"]))
# Out:
# Using TensorFlow backend.
# 2.1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# 0.6497618005520938
# 0.7399192281208788
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:3 of 600 iterations saturated the maximum tree depth of 10 (0.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:1 of 600 iterations saturated the maximum tree depth of 10 (0.167 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:43 of 600 iterations ended with a divergence (7.17 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:489 of 600 iterations saturated the maximum tree depth of 10 (81.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:476 of 600 iterations saturated the maximum tree depth of 10 (79.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:1 of 600 iterations ended with a divergence (0.167 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:3 of 600 iterations saturated the maximum tree depth of 10 (0.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:211 of 600 iterations saturated the maximum tree depth of 10 (35.2 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:556 of 600 iterations saturated the maximum tree depth of 10 (92.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:3 of 600 iterations saturated the maximum tree depth of 10 (0.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:17 of 600 iterations saturated the maximum tree depth of 10 (2.83 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:4 of 600 iterations saturated the maximum tree depth of 10 (0.667 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:47 of 600 iterations ended with a divergence (7.83 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:532 of 600 iterations saturated the maximum tree depth of 10 (88.7 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:2 of 600 iterations ended with a divergence (0.333 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:557 of 600 iterations saturated the maximum tree depth of 10 (92.8 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:156 of 600 iterations saturated the maximum tree depth of 10 (26 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:21 of 600 iterations saturated the maximum tree depth of 10 (3.5 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:26 of 600 iterations saturated the maximum tree depth of 10 (4.33 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:16 of 600 iterations ended with a divergence (2.67 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:571 of 600 iterations saturated the maximum tree depth of 10 (95.2 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:132 of 600 iterations saturated the maximum tree depth of 10 (22 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:236 of 600 iterations saturated the maximum tree depth of 10 (39.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:554 of 600 iterations saturated the maximum tree depth of 10 (92.3 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# 1
# 1
# 54 27
# 76
# X shape: (76, 4, 1)
# Y shape: (76, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# 0.63   1.00    0.15    0.40    0.19
# 1.00   0.15    0.40    0.19    -0.24
# 0.15   0.40    0.19    -0.24    -0.00
# 0.40   0.19    -0.24    -0.00    0.16
# 0.19   -0.24    -0.00    0.16    -0.01
# -0.24   -0.00    0.16    -0.01    0.10
# -0.00   0.16    -0.01    0.10    -0.00
# 0.16   -0.01    0.10    -0.00    -0.08
# -0.01   0.10    -0.00    -0.08    -0.11
# 0.10   -0.00    -0.08    -0.11    -0.09
# -0.00   -0.08    -0.11    -0.09    0.10
# -0.08   -0.11    -0.09    0.10    -0.16
# -0.11   -0.09    0.10    -0.16    -0.00
# -0.09   0.10    -0.16    -0.00    -0.11
# 0.10   -0.16    -0.00    -0.11    -0.44
# -0.16   -0.00    -0.11    -0.44    0.60
# -0.00   -0.11    -0.44    0.60    0.54
# -0.11   -0.44    0.60    0.54    0.69
# -0.44   0.60    0.54    0.69    0.49
# 0.60   0.54    0.69    0.49    -0.06
# 0.54   0.69    0.49    -0.06    0.04
# 0.69   0.49    -0.06    0.04    0.90
# Epoch 4/50
#  - 0s - loss: 0.2023
# Epoch 5/50
#  - 0s - loss: 0.1929
# Epoch 6/50
#  - 0s - loss: 0.1846
# Epoch 7/50
#  - 0s - loss: 0.1782
# Epoch 8/50
#  - 0s - loss: 0.1732
# Epoch 9/50
#  - 0s - loss: 0.1702
# Epoch 10/50
#  - 0s - loss: 0.1665
# Epoch 11/50
#  - 0s - loss: 0.1651
# Epoch 12/50
#  - 0s - loss: 0.1640
# Epoch 13/50
#  - 0s - loss: 0.1642
# Epoch 14/50
#  - 0s - loss: 0.1633
# Epoch 15/50
#  - 0s - loss: 0.1631
# Epoch 16/50
#  - 0s - loss: 0.1637
# Epoch 17/50
#  - 0s - loss: 0.1622
# Epoch 18/50
#  - 0s - loss: 0.1642
# Epoch 19/50
#  - 0s - loss: 0.1632
# Epoch 20/50
#  - 0s - loss: 0.1622
# Epoch 21/50
#  - 0s - loss: 0.1634
# Epoch 22/50
#  - 0s - loss: 0.1635
# Epoch 23/50
#  - 0s - loss: 0.1616
# Epoch 24/50
#  - 0s - loss: 0.1638
# Epoch 25/50
#  - 0s - loss: 0.1615
# Epoch 26/50
#  - 0s - loss: 0.1622
# Epoch 27/50
#  - 0s - loss: 0.1625
# Epoch 28/50
#  - 0s - loss: 0.1637
# Epoch 29/50
#  - 0s - loss: 0.1630
# Epoch 30/50
#  - 0s - loss: 0.1622
# Epoch 31/50
#  - 0s - loss: 0.1622
# Epoch 32/50
#  - 0s - loss: 0.1630
# Epoch 33/50
#  - 0s - loss: 0.1621
# Epoch 34/50
#  - 0s - loss: 0.1623
# Epoch 35/50
#  - 0s - loss: 0.1636
# Epoch 36/50
#  - 0s - loss: 0.1611
# Epoch 37/50
#  - 0s - loss: 0.1624
# Epoch 38/50
#  - 0s - loss: 0.1631
# Epoch 39/50
#  - 0s - loss: 0.1630
# Epoch 40/50
#  - 0s - loss: 0.1646
# Epoch 41/50
#  - 0s - loss: 0.1612
# Epoch 42/50
#  - 0s - loss: 0.1613
# Epoch 43/50
#  - 0s - loss: 0.1620
# Epoch 44/50
#  - 0s - loss: 0.1622
# Epoch 45/50
#  - 0s - loss: 0.1631
# Epoch 46/50
#  - 0s - loss: 0.1604
# Epoch 47/50
#  - 0s - loss: 0.1623
# Epoch 48/50
#  - 0s - loss: 0.1618
# Epoch 49/50
#  - 0s - loss: 0.1614
# Epoch 50/50
#  - 0s - loss: 0.1634
# trainY shape: (52, 1)
# trainPredict shape: (52, 1)
# testY shape: (25, 1)
# testPredict shape: (25, 1)
# Train Score: 2972.68 RMSE
# Test Score: 2822.00 RMSE
# 1
# 21
# 60 30
# 85
# X shape: (85, 4, 1)
# Y shape: (85, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.55   -0.32    -0.35    -0.68    -0.53
# -0.32   -0.35    -0.68    -0.53    -0.62
# -0.35   -0.68    -0.53    -0.62    -0.60
# -0.68   -0.53    -0.62    -0.60    -0.74
# -0.53   -0.62    -0.60    -0.74    -0.81
# -0.62   -0.60    -0.74    -0.81    -0.82
# -0.60   -0.74    -0.81    -0.82    -0.61
# -0.63   0.27    -0.63    -0.45    -0.48
# 0.27   -0.63    -0.45    -0.48    -0.30
# -0.63   -0.45    -0.48    -0.30    -0.51
# -0.45   -0.48    -0.30    -0.51    -0.17
# -0.48   -0.30    -0.51    -0.17    -0.50
# -0.30   -0.51    -0.17    -0.50    0.43
# -0.51   -0.17    -0.50    0.43    -0.54
# -0.17   -0.50    0.43    -0.54    0.08
# -0.50   0.43    -0.54    0.08    1.00
# 0.43   -0.54    0.08    1.00    -0.40
# -0.54   0.08    1.00    -0.40    -0.15
# 0.08   1.00    -0.40    -0.15    0.36
# 1.00   -0.40    -0.15    0.36    0.15
# -0.40   -0.15    0.36    0.15    -0.65
# -0.15   0.36    0.15    -0.65    0.11
# 0.36   0.15    -0.65    0.11    -0.59
# 0.15   -0.65    0.11    -0.59    0.34
# X shape: (85, 1, 4)
# 58
# 28
# Original trainX shape: (58, 1, 1)
# New trainX shape: (58, 1, 1)
# trainY shape: (58, 1)
# trainY example: [-0.32074222]
# Epoch 1/50
#  - 0s - loss: 0.2554
# Epoch 2/50
#  - 0s - loss: 0.1092
# Epoch 3/50
#  - 0s - loss: 0.0750
# Epoch 4/50
#  - 0s - loss: 0.0708
# Epoch 5/50
#  - 0s - loss: 0.0717
# Epoch 6/50
#  - 0s - loss: 0.0702
# Epoch 7/50
#  - 0s - loss: 0.0688
# Epoch 8/50
#  - 0s - loss: 0.0670
# Epoch 9/50
#  - 0s - loss: 0.0666
# Epoch 10/50
#  - 0s - loss: 0.0655
# Epoch 11/50
#  - 0s - loss: 0.0653
# Epoch 12/50
#  - 0s - loss: 0.0642
# Epoch 13/50
#  - 0s - loss: 0.0636
# Epoch 14/50
#  - 0s - loss: 0.0623
# Epoch 15/50
#  - 0s - loss: 0.0615
# Epoch 16/50
#  - 0s - loss: 0.0615
# Epoch 17/50
#  - 0s - loss: 0.0620
# Epoch 18/50
#  - 0s - loss: 0.0611
# Epoch 19/50
#  - 0s - loss: 0.0603
# Epoch 20/50
#  - 0s - loss: 0.0599
# Epoch 21/50
#  - 0s - loss: 0.0615
# Epoch 22/50
#  - 0s - loss: 0.0594
# Epoch 23/50
#  - 0s - loss: 0.0595
# Epoch 24/50
#  - 0s - loss: 0.0597
# Epoch 25/50
#  - 0s - loss: 0.0604
# Epoch 26/50
#  - 0s - loss: 0.0589
# Epoch 27/50
#  - 0s - loss: 0.0602
# Epoch 28/50
#  - 0s - loss: 0.0590
# Epoch 29/50
#  - 0s - loss: 0.0584
# Epoch 30/50
#  - 0s - loss: 0.0595
# Epoch 31/50
#  - 0s - loss: 0.0598
# Epoch 32/50
#  - 0s - loss: 0.0594
# Epoch 33/50
#  - 0s - loss: 0.0592
# Epoch 34/50
#  - 0s - loss: 0.0586
# Epoch 35/50
#  - 0s - loss: 0.0582
# Epoch 36/50
#  - 0s - loss: 0.0578
# Epoch 37/50
#  - 0s - loss: 0.0593
# Epoch 38/50
#  - 0s - loss: 0.0582
# Epoch 39/50
#  - 0s - loss: 0.0585
# Epoch 40/50
#  - 0s - loss: 0.0592
# Epoch 41/50
#  - 0s - loss: 0.0575
# Epoch 42/50
#  - 0s - loss: 0.0591
# Epoch 43/50
#  - 0s - loss: 0.0589
# Epoch 44/50
#  - 0s - loss: 0.0585
# Epoch 45/50
#  - 0s - loss: 0.0585
# Epoch 46/50
#  - 0s - loss: 0.0583
# Epoch 47/50
#  - 0s - loss: 0.0583
# Epoch 48/50
#  - 0s - loss: 0.0585
# Epoch 49/50
#  - 0s - loss: 0.0583
# Epoch 50/50
#  - 0s - loss: 0.0588
# trainY shape: (58, 1)
# trainPredict shape: (58, 1)
# testY shape: (28, 1)
# testPredict shape: (28, 1)
# Train Score: 6428.43 RMSE
# Test Score: 13832.22 RMSE
# 1
# 29
# 60 30
# 85
# X shape: (85, 4, 1)
# Y shape: (85, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.28   -0.66    -0.15    -0.59    -0.14
# -0.66   -0.15    -0.59    -0.14    0.17
# -0.15   -0.59    -0.14    0.17    -0.22
# -0.59   -0.14    0.17    -0.22    -0.45
# -0.14   0.17    -0.22    -0.45    -0.40
# 0.17   -0.22    -0.45    -0.40    -0.80
# -0.22   -0.45    -0.40    -0.80    0.06
# -0.45   -0.40    -0.80    0.06    -0.31
# -0.40   -0.80    0.06    -0.31    -0.07
# -0.80   0.06    -0.31    -0.07    -0.63
# 0.06   -0.31    -0.07    -0.63    -0.19
# -0.31   -0.07    -0.63    -0.19    -0.55
# -0.07   -0.63    -0.19    -0.55    -0.11
# -0.63   -0.19    -0.55    -0.11    -0.67
# -0.19   -0.55    -0.11    -0.67    0.08
# -0.55   -0.11    -0.67    0.08    0.24
# -0.11   -0.67    0.08    0.24    0.40
# -0.67   0.08    0.24    0.40    0.12
# 0.08   0.24    0.40    0.12    0.15
# 0.24   0.40    0.12    0.15    -0.42
# 0.40   0.12    0.15    -0.42    -0.06
# 0.12   0.15    -0.42    -0.06    -0.11
# 0.15   -0.42    -0.06    -0.11    -1.00
# -0.42   -0.06    -0.11    -1.00    -0.48
# -0.06   -0.11    -1.00    -0.48    0.20
# -0.11   -1.00    -0.48    0.20    -0.13
# -1.00   -0.48    0.20    -0.13    -0.21
# -0.48   0.20    -0.13    -0.21    -0.26
# 0.20   -0.13    -0.21    -0.26    -0.81
# -0.13   -0.21    -0.26    -0.81    -0.84
# -0.21   -0.26    -0.81    -0.84    -0.36
# -0.26   -0.81    -0.84    -0.36    -0.34
# -0.81   -0.84    -0.36    -0.34    0.09
# -0.84   -0.36    -0.34    0.09    -0.38
# -0.36   -0.34    0.09    -0.38    -0.02
# -0.34   0.09    -0.38    -0.02    -0.27
# 0.09   -0.38    -0.02    -0.27    -0.72
# -0.38   -0.02    -0.27    -0.72    -0.63
# -0.02   -0.27    -0.72    -0.63    -0.09
# -0.27   -0.72    -0.63    -0.09    -0.16
# -0.72   -0.63    -0.09    -0.16    -0.33
# -0.63   -0.09    -0.16    -0.33    0.32
# -0.09   -0.16    -0.33    0.32    -0.19
# -0.16   -0.33    0.32    -0.19    -0.60
# -0.33   0.32    -0.19    -0.60    -0.51
# Epoch 18/50
#  - 0s - loss: 0.1048
# Epoch 19/50
#  - 0s - loss: 0.1052
# Epoch 20/50
#  - 0s - loss: 0.1057
# Epoch 21/50
#  - 0s - loss: 0.1047
# Epoch 22/50
#  - 0s - loss: 0.1047
# Epoch 23/50
#  - 0s - loss: 0.1065
# Epoch 24/50
#  - 0s - loss: 0.1064
# Epoch 25/50
#  - 0s - loss: 0.1062
# Epoch 26/50
#  - 0s - loss: 0.1049
# Epoch 27/50
#  - 0s - loss: 0.1057
# Epoch 28/50
#  - 0s - loss: 0.1053
# Epoch 29/50
#  - 0s - loss: 0.1049
# Epoch 30/50
#  - 0s - loss: 0.1071
# Epoch 31/50
#  - 0s - loss: 0.1060
# Epoch 32/50
#  - 0s - loss: 0.1059
# Epoch 33/50
#  - 0s - loss: 0.1062
# Epoch 34/50
#  - 0s - loss: 0.1041
# Epoch 35/50
#  - 0s - loss: 0.1042
# Epoch 36/50
#  - 0s - loss: 0.1040
# Epoch 37/50
#  - 0s - loss: 0.1045
# Epoch 38/50
#  - 0s - loss: 0.1064
# Epoch 39/50
#  - 0s - loss: 0.1056
# Epoch 40/50
#  - 0s - loss: 0.1042
# Epoch 41/50
#  - 0s - loss: 0.1049
# Epoch 42/50
#  - 0s - loss: 0.1048
# Epoch 43/50
#  - 0s - loss: 0.1043
# Epoch 44/50
#  - 0s - loss: 0.1079
# Epoch 45/50
#  - 0s - loss: 0.1037
# Epoch 46/50
#  - 0s - loss: 0.1043
# Epoch 47/50
#  - 0s - loss: 0.1046
# Epoch 48/50
#  - 0s - loss: 0.1049
# Epoch 49/50
#  - 0s - loss: 0.1053
# Epoch 50/50
#  - 0s - loss: 0.1044
# trainY shape: (58, 1)
# trainPredict shape: (58, 1)
# testY shape: (28, 1)
# testPredict shape: (28, 1)
# Train Score: 3573.54 RMSE
# Test Score: 5654.83 RMSE
# 1
# 48
# 54 27
# 76
# X shape: (76, 4, 1)
# Y shape: (76, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.87   -0.45    -0.54    -0.99    -0.94
# -0.45   -0.54    -0.99    -0.94    -0.88
# -0.54   -0.99    -0.94    -0.88    -0.92
# -0.99   -0.94    -0.88    -0.92    -0.95
# -0.94   -0.88    -0.92    -0.95    -0.99
# -0.88   -0.92    -0.95    -0.99    -0.94
# -0.92   -0.95    -0.99    -0.94    -0.83
# -0.95   -0.99    -0.94    -0.83    -0.96
# -0.99   -0.94    -0.83    -0.96    -0.87
# -0.94   -0.83    -0.96    -0.87    -0.99
# -0.83   -0.96    -0.87    -0.99    -0.92
# -0.96   -0.87    -0.99    -0.92    -0.99
# -0.87   -0.99    -0.92    -0.99    -0.99
# -0.99   -0.92    -0.99    -0.99    -0.97
# -0.92   -0.99    -0.99    -0.97    -0.97
# -0.99   -0.99    -0.97    -0.97    -0.93
# -0.99   -0.97    -0.97    -0.93    -0.95
# -0.97   -0.97    -0.93    -0.95    -0.92
# -0.97   -0.93    -0.95    -0.92    -0.98
# -0.93   -0.95    -0.92    -0.98    -0.95
# -0.95   -0.92    -0.98    -0.95    -0.95
# Epoch 3/50
#  - 0s - loss: 0.0795
# Epoch 4/50
#  - 0s - loss: 0.0779
# Epoch 5/50
#  - 0s - loss: 0.0772
# Epoch 6/50
#  - 0s - loss: 0.0777
# Epoch 7/50
#  - 0s - loss: 0.0772
# Epoch 8/50
#  - 0s - loss: 0.0774
# Epoch 9/50
#  - 0s - loss: 0.0771
# Epoch 10/50
#  - 0s - loss: 0.0761
# Epoch 11/50
#  - 0s - loss: 0.0776
# Epoch 12/50
#  - 0s - loss: 0.0780
# Epoch 13/50
#  - 0s - loss: 0.0776
# Epoch 14/50
#  - 0s - loss: 0.0764
# Epoch 15/50
#  - 0s - loss: 0.0779
# Epoch 16/50
#  - 0s - loss: 0.0758
# Epoch 17/50
#  - 0s - loss: 0.0759
# Epoch 18/50
#  - 0s - loss: 0.0756
# Epoch 19/50
#  - 0s - loss: 0.0759
# Epoch 20/50
#  - 0s - loss: 0.0754
# Epoch 21/50
#  - 0s - loss: 0.0759
# Epoch 22/50
#  - 0s - loss: 0.0757
# Epoch 23/50
#  - 0s - loss: 0.0750
# Epoch 24/50
#  - 0s - loss: 0.0754
# Epoch 25/50
#  - 0s - loss: 0.0751
# Epoch 26/50
#  - 0s - loss: 0.0750
# Epoch 27/50
#  - 0s - loss: 0.0745
# Epoch 28/50
#  - 0s - loss: 0.0752
# Epoch 29/50
#  - 0s - loss: 0.0746
# Epoch 30/50
#  - 0s - loss: 0.0749
# Epoch 31/50
#  - 0s - loss: 0.0740
# Epoch 32/50
#  - 0s - loss: 0.0754
# Epoch 33/50
#  - 0s - loss: 0.0756
# Epoch 34/50
#  - 0s - loss: 0.0752
# Epoch 35/50
#  - 0s - loss: 0.0751
# Epoch 36/50
#  - 0s - loss: 0.0747
# Epoch 37/50
#  - 0s - loss: 0.0743
# Epoch 38/50
#  - 0s - loss: 0.0739
# Epoch 39/50
#  - 0s - loss: 0.0740
# Epoch 40/50
#  - 0s - loss: 0.0733
# Epoch 41/50
#  - 0s - loss: 0.0743
# Epoch 42/50
#  - 0s - loss: 0.0738
# Epoch 43/50
#  - 0s - loss: 0.0730
# Epoch 44/50
#  - 0s - loss: 0.0734
# Epoch 45/50
#  - 0s - loss: 0.0730
# Epoch 46/50
#  - 0s - loss: 0.0736
# Epoch 47/50
#  - 0s - loss: 0.0729
# Epoch 48/50
#  - 0s - loss: 0.0733
# Epoch 49/50
#  - 0s - loss: 0.0733
# Epoch 50/50
#  - 0s - loss: 0.0727
# trainY shape: (52, 1)
# trainPredict shape: (52, 1)
# testY shape: (25, 1)
# testPredict shape: (25, 1)
# Train Score: 6203.71 RMSE
# Test Score: 4173.95 RMSE
# 1
# 31
# 56 29
# 80
# X shape: (80, 4, 1)
# Y shape: (80, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.80   -0.87    -0.82    -0.86    -0.80
# -0.87   -0.82    -0.86    -0.80    -0.75
# -0.82   -0.86    -0.80    -0.75    0.00
# -0.86   -0.80    -0.75    0.00    -0.99
# -0.80   -0.75    0.00    -0.99    -0.77
# -0.75   0.00    -0.99    -0.77    -0.49
# 0.00   -0.99    -0.77    -0.49    -0.77
# -0.99   -0.77    -0.49    -0.77    -0.81
# -0.77   -0.49    -0.77    -0.81    -0.85
# -0.49   -0.77    -0.81    -0.85    -0.73
# -0.77   -0.81    -0.85    -0.73    -0.83
# -0.81   -0.85    -0.73    -0.83    -0.68
# -0.85   -0.73    -0.83    -0.68    -0.82
# -0.73   -0.83    -0.68    -0.82    -0.78
# X shape: (80, 1, 4)
# 54
# 27
# Original trainX shape: (54, 1, 1)
# New trainX shape: (54, 1, 1)
# trainY shape: (54, 1)
# trainY example: [-0.93175682]
# Epoch 1/50
#  - 0s - loss: 0.5735
# Epoch 2/50
#  - 0s - loss: 0.1621
# Epoch 3/50
#  - 0s - loss: 0.0121
# Epoch 4/50
#  - 0s - loss: 0.0052
# Epoch 5/50
#  - 0s - loss: 0.0051
# Epoch 6/50
#  - 0s - loss: 0.0051
# Epoch 7/50
#  - 0s - loss: 0.0054
# Epoch 8/50
#  - 0s - loss: 0.0051
# Epoch 9/50
#  - 0s - loss: 0.0052
# Epoch 10/50
#  - 0s - loss: 0.0051
# Epoch 11/50
#  - 0s - loss: 0.0054
# Epoch 12/50
#  - 0s - loss: 0.0050
# Epoch 13/50
#  - 0s - loss: 0.0054
# Epoch 14/50
#  - 0s - loss: 0.0052
# Epoch 15/50
#  - 0s - loss: 0.0057
# Epoch 16/50
#  - 0s - loss: 0.0053
# Epoch 17/50
#  - 0s - loss: 0.0054
# Epoch 18/50
#  - 0s - loss: 0.0051
# Epoch 19/50
#  - 0s - loss: 0.0051
# Epoch 20/50
#  - 0s - loss: 0.0051
# Epoch 21/50
#  - 0s - loss: 0.0052
# Epoch 22/50
#  - 0s - loss: 0.0052
# Epoch 23/50
#  - 0s - loss: 0.0055
# Epoch 24/50
#  - 0s - loss: 0.0054
# Epoch 25/50
#  - 0s - loss: 0.0051
# Epoch 26/50
#  - 0s - loss: 0.0053
# Epoch 27/50
#  - 0s - loss: 0.0054
# Epoch 28/50
#  - 0s - loss: 0.0052
# Epoch 29/50
#  - 0s - loss: 0.0052
# Epoch 30/50
#  - 0s - loss: 0.0054
# Epoch 31/50
#  - 0s - loss: 0.0054
# Epoch 32/50
#  - 0s - loss: 0.0051
# Epoch 33/50
#  - 0s - loss: 0.0049
# Epoch 34/50
#  - 0s - loss: 0.0055
# Epoch 35/50
#  - 0s - loss: 0.0052
# Epoch 36/50
#  - 0s - loss: 0.0055
# Epoch 37/50
#  - 0s - loss: 0.0053
# Epoch 38/50
#  - 0s - loss: 0.0052
# Epoch 39/50
#  - 0s - loss: 0.0054
# Epoch 40/50
#  - 0s - loss: 0.0051
# Epoch 41/50
#  - 0s - loss: 0.0053
# Epoch 42/50
#  - 0s - loss: 0.0055
# -0.39   -0.51    -0.24    -0.84    -0.89
# -0.51   -0.24    -0.84    -0.89    -0.97
# -0.24   -0.84    -0.89    -0.97    -0.75
# -0.84   -0.89    -0.97    -0.75    -0.74
# -0.89   -0.97    -0.75    -0.74    -0.74
# -0.97   -0.75    -0.74    -0.74    -0.62
# -0.75   -0.74    -0.74    -0.62    -0.77
# -0.74   -0.74    -0.62    -0.77    -0.81
# -0.74   -0.62    -0.77    -0.81    -0.82
# -0.62   -0.77    -0.81    -0.82    -0.92
# -0.77   -0.81    -0.82    -0.92    -0.98
# -0.81   -0.82    -0.92    -0.98    -0.98
# -0.82   -0.92    -0.98    -0.98    -0.87
# -0.92   -0.98    -0.98    -0.87    -0.96
# -0.98   -0.98    -0.87    -0.96    -1.00
# -0.98   -0.87    -0.96    -1.00    -0.97
# -0.87   -0.96    -1.00    -0.97    -1.00
# -0.96   -1.00    -0.97    -1.00    -0.97
# -1.00   -0.97    -1.00    -0.97    -0.94
# -0.97   -1.00    -0.97    -0.94    -0.50
# -1.00   -0.97    -0.94    -0.50    -0.92
# -0.97   -0.94    -0.50    -0.92    -0.78
# -0.94   -0.50    -0.92    -0.78    -0.74
# -0.50   -0.92    -0.78    -0.74    -0.69
# -0.92   -0.78    -0.74    -0.69    -0.93
# -0.78   -0.74    -0.69    -0.93    -0.80
# -0.74   -0.69    -0.93    -0.80    -0.87
# -0.69   -0.93    -0.80    -0.87    -0.41
# X shape: (76, 1, 4)
# 52
# 25
# Original trainX shape: (52, 1, 1)
# New trainX shape: (52, 1, 1)
# trainY shape: (52, 1)
# trainY example: [0.3678653]
# Epoch 1/50
#  - 0s - loss: 0.1923
# Epoch 2/50
#  - 0s - loss: 0.1689
# Epoch 3/50
#  - 0s - loss: 0.1632
# Epoch 4/50
#  - 0s - loss: 0.1611
# Epoch 5/50
#  - 0s - loss: 0.1587
# Epoch 6/50
#  - 0s - loss: 0.1569
# Epoch 7/50
#  - 0s - loss: 0.1569
# Epoch 8/50
#  - 0s - loss: 0.1542
# Epoch 9/50
#  - 0s - loss: 0.1540
# Epoch 10/50
#  - 0s - loss: 0.1530
# Epoch 11/50
#  - 0s - loss: 0.1513
# Epoch 12/50
#  - 0s - loss: 0.1513
# Epoch 13/50
#  - 0s - loss: 0.1505
# Epoch 14/50
#  - 0s - loss: 0.1496
# Epoch 15/50
#  - 0s - loss: 0.1498
# Epoch 16/50
#  - 0s - loss: 0.1501
# Epoch 17/50
#  - 0s - loss: 0.1486
# Epoch 18/50
#  - 0s - loss: 0.1481
# Epoch 19/50
#  - 0s - loss: 0.1471
# Epoch 20/50
#  - 0s - loss: 0.1473
# Epoch 21/50
#  - 0s - loss: 0.1461
# Epoch 22/50
#  - 0s - loss: 0.1448
# Epoch 23/50
#  - 0s - loss: 0.1457
# Epoch 24/50
#  - 0s - loss: 0.1461
# Epoch 25/50
#  - 0s - loss: 0.1443
# Epoch 26/50
#  - 0s - loss: 0.1447
# Epoch 27/50
#  - 0s - loss: 0.1447
# Epoch 28/50
# ...
#  - 0s - loss: 0.1254
# -0.57   -0.51    -0.55    -0.50    -0.46
# -0.51   -0.55    -0.50    -0.46    -0.69
# -0.55   -0.50    -0.46    -0.69    -0.33
# -0.50   -0.46    -0.69    -0.33    -0.64
# -0.46   -0.69    -0.33    -0.64    -1.00
# -0.69   -0.33    -0.64    -1.00    0.01
# -0.33   -0.64    -1.00    0.01    -0.81
# -0.64   -1.00    0.01    -0.81    -0.81
# -1.00   0.01    -0.81    -0.81    -0.86
# 0.01   -0.81    -0.81    -0.86    -0.55
# -0.81   -0.81    -0.86    -0.55    -0.67
# -0.81   -0.86    -0.55    -0.67    -0.78
# -0.86   -0.55    -0.67    -0.78    -0.60
# -0.55   -0.67    -0.78    -0.60    -0.74
# -0.67   -0.78    -0.60    -0.74    -0.66
# -0.78   -0.60    -0.74    -0.66    -0.80
# -0.60   -0.74    -0.66    -0.80    -0.69
# -0.74   -0.66    -0.80    -0.69    0.24
# -0.66   -0.80    -0.69    0.24    -0.82
# -0.80   -0.69    0.24    -0.82    -0.53
# -0.69   0.24    -0.82    -0.53    -0.50
# 0.24   -0.82    -0.53    -0.50    -0.55
# -0.82   -0.53    -0.50    -0.55    -0.88
# -0.53   -0.50    -0.55    -0.88    -0.40
# -0.50   -0.55    -0.88    -0.40    -0.38
# -0.55   -0.88    -0.40    -0.38    -0.73
# -0.88   -0.40    -0.38    -0.73    -0.62
# -0.40   -0.38    -0.73    -0.62    -0.87
# -0.38   -0.73    -0.62    -0.87    0.02
# -0.73   -0.62    -0.87    0.02    -0.42
# -0.62   -0.87    0.02    -0.42    -0.67
# -0.87   0.02    -0.42    -0.67    -0.49
# 0.02   -0.42    -0.67    -0.49    -0.15
# -0.42   -0.67    -0.49    -0.15    -0.48
# -0.67   -0.49    -0.15    -0.48    -0.34
# -0.49   -0.15    -0.48    -0.34    -0.10
# -0.15   -0.48    -0.34    -0.10    0.94
# X shape: (85, 1, 4)
# 58
# 28
# Original trainX shape: (58, 1, 1)
# New trainX shape: (58, 1, 1)
# trainY shape: (58, 1)
# trainY example: [-0.24435119]
# Epoch 1/50
#  - 0s - loss: 0.1802
# Epoch 2/50
#  - 0s - loss: 0.1042
# Epoch 3/50
#  - 0s - loss: 0.0983
# Epoch 4/50
#  - 0s - loss: 0.0978
# Epoch 5/50
#  - 0s - loss: 0.0972
# Epoch 6/50
#  - 0s - loss: 0.0976
# Epoch 7/50
#  - 0s - loss: 0.0971
# Epoch 8/50
#  - 0s - loss: 0.0993
# Epoch 9/50
#  - 0s - loss: 0.0978
# Epoch 10/50
#  - 0s - loss: 0.0987
# Epoch 11/50
#  - 0s - loss: 0.1004
# Epoch 12/50
#  - 0s - loss: 0.0978
# Epoch 13/50
#  - 0s - loss: 0.0975
# Epoch 14/50
#  - 0s - loss: 0.0972
# Epoch 15/50
#  - 0s - loss: 0.1007
# Epoch 16/50
#  - 0s - loss: 0.0963
# Epoch 17/50
#  - 0s - loss: 0.0973
# Epoch 18/50
#  - 0s - loss: 0.0969
# Epoch 19/50
#  - 0s - loss: 0.0970
# Epoch 20/50
#  - 0s - loss: 0.0968
# Epoch 21/50
#  - 0s - loss: 0.0971
# Epoch 22/50
#  - 0s - loss: 0.0975
# Epoch 23/50
#  - 0s - loss: 0.0982
# Epoch 24/50
#  - 0s - loss: 0.0970
# Epoch 25/50
#  - 0s - loss: 0.0976
# Epoch 26/50
#  - 0s - loss: 0.0973
# Epoch 27/50
#  - 0s - loss: 0.0975
# Epoch 28/50
#  - 0s - loss: 0.0971
# Epoch 29/50
#  - 0s - loss: 0.0965
# Epoch 30/50
#  - 0s - loss: 0.0980
# Epoch 31/50
#  - 0s - loss: 0.0976
# Epoch 32/50
#  - 0s - loss: 0.0962
# Epoch 33/50
#  - 0s - loss: 0.0968
# Epoch 34/50
#  - 0s - loss: 0.0973
# Epoch 35/50
#  - 0s - loss: 0.0970
# Epoch 36/50
#  - 0s - loss: 0.0989
# Epoch 37/50
#  - 0s - loss: 0.0962
# Epoch 38/50
#  - 0s - loss: 0.0968
# Epoch 39/50
#  - 0s - loss: 0.0967
# Epoch 40/50
#  - 0s - loss: 0.0993
# Epoch 41/50
#  - 0s - loss: 0.0973
# Epoch 42/50
#  - 0s - loss: 0.0965
# Epoch 43/50
#  - 0s - loss: 0.0971
# Epoch 44/50
#  - 0s - loss: 0.0970
# Epoch 45/50
#  - 0s - loss: 0.0970
# Epoch 46/50
#  - 0s - loss: 0.0986
# Epoch 47/50
#  - 0s - loss: 0.0986
# Epoch 48/50
#  - 0s - loss: 0.0979
# Epoch 49/50
#  - 0s - loss: 0.0968
# Epoch 50/50
#  - 0s - loss: 0.0965
# trainY shape: (58, 1)
# trainPredict shape: (58, 1)
# testY shape: (28, 1)
# testPredict shape: (28, 1)
# Train Score: 2071.52 RMSE
# Test Score: 2554.15 RMSE
# 12
# 48
# 51 26
# 72
# X shape: (72, 4, 1)
# Y shape: (72, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.91   -0.35    0.01    -0.88    -0.85
# -0.35   0.01    -0.88    -0.85    -0.91
# 0.01   -0.88    -0.85    -0.91    -0.90
# -0.88   -0.85    -0.91    -0.90    -0.90
# -0.85   -0.91    -0.90    -0.90    -0.98
# -0.91   -0.90    -0.90    -0.98    -1.00
# -0.90   -0.90    -0.98    -1.00    -0.79
# -0.90   -0.98    -1.00    -0.79    -0.85
# -0.98   -1.00    -0.79    -0.85    -0.69
# -1.00   -0.79    -0.85    -0.69    -0.98
# -0.79   -0.85    -0.69    -0.98    -1.00
# -0.85   -0.69    -0.98    -1.00    -0.98
# -0.69   -0.98    -1.00    -0.98    -0.78
# -0.98   -1.00    -0.98    -0.78    -0.92
# -1.00   -0.98    -0.78    -0.92    -0.92
# -0.98   -0.78    -0.92    -0.92    -0.94
# -0.78   -0.92    -0.92    -0.94    -0.83
# -0.92   -0.92    -0.94    -0.83    -0.81
# -0.92   -0.94    -0.83    -0.81    -0.88
# -0.94   -0.83    -0.81    -0.88    -0.88
# -0.83   -0.81    -0.88    -0.88    -0.98
# -0.81   -0.88    -0.88    -0.98    -0.88
# -0.88   -0.88    -0.98    -0.88    -0.99
# -0.88   -0.98    -0.88    -0.99    -0.98
# Epoch 10/50
#  - 0s - loss: 0.1771
# Epoch 11/50
#  - 0s - loss: 0.1762
# Epoch 12/50
#  - 0s - loss: 0.1786
# Epoch 13/50
#  - 0s - loss: 0.1753
# Epoch 14/50
#  - 0s - loss: 0.1793
# Epoch 15/50
#  - 0s - loss: 0.1766
# Epoch 16/50
#  - 0s - loss: 0.1764
# Epoch 17/50
#  - 0s - loss: 0.1770
# Epoch 18/50
#  - 0s - loss: 0.1765
# Epoch 19/50
#  - 0s - loss: 0.1767
# Epoch 20/50
#  - 0s - loss: 0.1755
# Epoch 21/50
#  - 0s - loss: 0.1758
# Epoch 22/50
#  - 0s - loss: 0.1753
# Epoch 23/50
#  - 0s - loss: 0.1825
# Epoch 24/50
#  - 0s - loss: 0.1758
# Epoch 25/50
#  - 0s - loss: 0.1770
# Epoch 26/50
#  - 0s - loss: 0.1752
# Epoch 27/50
#  - 0s - loss: 0.1750
# Epoch 28/50
#  - 0s - loss: 0.1758
# Epoch 29/50
#  - 0s - loss: 0.1745
# Epoch 30/50
#  - 0s - loss: 0.1744
# Epoch 31/50
#  - 0s - loss: 0.1783
# Epoch 32/50
#  - 0s - loss: 0.1743
# Epoch 33/50
#  - 0s - loss: 0.1746
# Epoch 34/50
#  - 0s - loss: 0.1780
# Epoch 35/50
#  - 0s - loss: 0.1758
# Epoch 36/50
#  - 0s - loss: 0.1759
# Epoch 37/50
#  - 0s - loss: 0.1770
# Epoch 38/50
#  - 0s - loss: 0.1797
# Epoch 39/50
#  - 0s - loss: 0.1738
# Epoch 40/50
#  - 0s - loss: 0.1745
# Epoch 41/50
#  - 0s - loss: 0.1739
# Epoch 42/50
#  - 0s - loss: 0.1742
# Epoch 43/50
#  - 0s - loss: 0.1737
# Epoch 44/50
#  - 0s - loss: 0.1755
# Epoch 45/50
#  - 0s - loss: 0.1754
# Epoch 46/50
#  - 0s - loss: 0.1766
# Epoch 47/50
#  - 0s - loss: 0.1731
# Epoch 48/50
#  - 0s - loss: 0.1737
# Epoch 49/50
#  - 0s - loss: 0.1751
# Epoch 50/50
#  - 0s - loss: 0.1734
# trainY shape: (49, 1)
# trainPredict shape: (49, 1)
# testY shape: (24, 1)
# testPredict shape: (24, 1)
# Train Score: 4623.37 RMSE
# Test Score: 4542.55 RMSE
# 12
# 31
# 50 26
# 71
# X shape: (71, 4, 1)
# Y shape: (71, 1)
# Xt-3     Xt-2      Xt-1      Xt        Y
# ---------------------------------------------
# -0.99   -0.96    -0.99    -0.99    -0.99
# -0.96   -0.99    -0.99    -0.99    -0.99
# -0.99   -0.99    -0.99    -0.99    -0.99
# -0.99   -0.99    -0.99    -0.99    -0.96
# -0.99   -0.99    -0.99    -0.96    -0.92
# -0.99   -0.99    -0.96    -0.92    -0.99
# -0.99   -0.96    -0.92    -0.99    -0.93
# -0.96   -0.92    -0.99    -0.93    -0.99
# -0.92   -0.99    -0.93    -0.99    -0.93
# -0.99   -0.93    -0.99    -0.93    -0.93
# -0.93   -0.99    -0.93    -0.93    -0.96
# X shape: (71, 1, 4)
# 48
# 24
# Original trainX shape: (48, 1, 1)
# New trainX shape: (48, 1, 1)
# trainY shape: (48, 1)
# trainY example: [-0.96229171]
# Epoch 1/50
#  - 0s - loss: 0.5016
# Epoch 2/50
#  - 0s - loss: 0.1337
# Epoch 3/50
#  - 0s - loss: 0.0126
# Epoch 4/50
#  - 0s - loss: 0.0061
# Epoch 5/50
#  - 0s - loss: 0.0062
# Epoch 6/50
#  - 0s - loss: 0.0061
# Epoch 7/50
#  - 0s - loss: 0.0061
# Epoch 8/50
#  - 0s - loss: 0.0063
# Epoch 9/50
#  - 0s - loss: 0.0062
# Epoch 10/50
#  - 0s - loss: 0.0060
# Epoch 11/50
#  - 0s - loss: 0.0064
# Epoch 12/50
#  - 0s - loss: 0.0061
# Epoch 13/50
#  - 0s - loss: 0.0065
# Epoch 14/50
#  - 0s - loss: 0.0063
# Epoch 15/50
#  - 0s - loss: 0.0063
# Epoch 16/50
#  - 0s - loss: 0.0061
# Epoch 17/50
#  - 0s - loss: 0.0066
# Epoch 18/50
#  - 0s - loss: 0.0066
# Epoch 19/50
#  - 0s - loss: 0.0062
# Epoch 20/50
#  - 0s - loss: 0.0062
# Epoch 21/50
#  - 0s - loss: 0.0060
# Epoch 22/50
#  - 0s - loss: 0.0064
# Epoch 23/50
#  - 0s - loss: 0.0063
# Epoch 24/50
#  - 0s - loss: 0.0064
# Epoch 25/50
#  - 0s - loss: 0.0065
# Epoch 26/50
#  - 0s - loss: 0.0062
# Epoch 27/50
#  - 0s - loss: 0.0061
# Epoch 28/50
#  - 0s - loss: 0.0062
# Epoch 29/50
#  - 0s - loss: 0.0060
# Epoch 30/50
#  - 0s - loss: 0.0060
# Epoch 31/50
#  - 0s - loss: 0.0062
# Epoch 32/50
#  - 0s - loss: 0.0062
# Epoch 33/50
#  - 0s - loss: 0.0061
# Epoch 34/50
#  - 0s - loss: 0.0062
# Epoch 35/50
#  - 0s - loss: 0.0059
# Epoch 36/50
#  - 0s - loss: 0.0065
# Epoch 37/50
#  - 0s - loss: 0.0059
# Epoch 38/50
#  - 0s - loss: 0.0059
# Epoch 39/50
#  - 0s - loss: 0.0064
# Epoch 40/50
#  - 0s - loss: 0.0060
# Epoch 41/50
#  - 0s - loss: 0.0060
# Epoch 42/50
#  - 0s - loss: 0.0060
# Epoch 43/50
#  - 0s - loss: 0.0059
# Epoch 44/50
#  - 0s - loss: 0.0060
# Epoch 45/50
#  - 0s - loss: 0.0060
# Epoch 46/50
#  - 0s - loss: 0.0060
# Epoch 47/50
#  - 0s - loss: 0.0060
# Epoch 48/50
#  - 0s - loss: 0.0061
# Epoch 49/50
#  - 0s - loss: 0.0060
# Epoch 50/50
#  - 0s - loss: 0.0063
# trainY shape: (48, 1)
# trainPredict shape: (48, 1)
# testY shape: (24, 1)
# testPredict shape: (24, 1)
# Train Score: 1467.95 RMSE
# Test Score: 8724.36 RMSE
# Stacking =  0.7399192281208788
# FP =  0.2354031943958349
# LSTM =  0.6425342849026248
# AVG =  0.6460584936860508

# %%
10:50
